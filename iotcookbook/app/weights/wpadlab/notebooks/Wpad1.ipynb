# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('A simple chirp');

# %%
x = np.linspace(0, 3, 500)
plt.plot(x, 900+(100*np.log(x+0.004)))

# %%
x = np.linspace(0, 1024, 500)
plt.plot(x, np.exp((x - 900) / 100) - 0.004)

# %%
import requests

# %%
import requests, json
payload = {"procedure": "io.crossbar.examples.yun.weighingpad.get_series", "args": [1]}
r = requests.post("http://127.0.0.1:8080/call", data=json.dumps(payload))

# %%
r.text
# Out:
# u'<html><head><title>Processing Failed</title></head><body><b>Processing Failed</b></body></html>'

# %%
r = requests.post("http://127.0.0.1:8080/call", data=json.dumps(payload), headers={'content-type': 'application/json'})

# %%
r.json()
# Out:
# {u'args': [{u'A0': [141, 139, 141, 141, 142],
#    u'A1': [225, 225, 225, 225, 225],
#    u'A2': [183, 182, 183, 183, 183],
#    u'A3': [231, 233, 231, 231, 231],
#    u'A4': [113, 171, 317, 400, 433],
#    u'A5': [29, 25, 19, 44, 64],
#    u'A6': [22, 33, 151, 385, 603]}]}

# %%
import requests, json

def get_series(series_id):
    payload = {"procedure": "io.crossbar.demo.wpad.get_series", "args": [series_id]}
    r = requests.post("https://demo.crossbar.io/call", data=json.dumps(payload), headers={'content-type': 'application/json'})
    res = r.json()
    return res['args'][0]

# %%
series1 = get_series(1)

# %%
series1

# %%
series2['A4']
# Out:
# [154, 213, 238, 280, 295, 314, 322]

# %%
plt.bar(range(len(series2['A4'])), series2['A4'])
# Out:
# <Container object of 7 artists>

# %%
fig, ax = plt.subplots()
N = len(series2['A4'])
ind = np.arange(N)
width = 0.8 / float(N)
colors = ['r', 'b', 'g']
for i in range(3):
    ax.bar(ind + width * i, series2['A{}'.format(i + 4)], width, color=colors[i])

# %%
def plot_series(series):
    fig, ax = plt.subplots()
    N = len(series['A4'])
    ind = np.arange(N)
    width = 0.8 / float(N)
    colors = ['r', 'b', 'g']
    for i in range(3):
        ax.bar(ind + width * i, series['A{}'.format(i + 4)], width, color=colors[i])

# %%
plot_series(series2)

# %%
series3 = get_series(3)

# %%
series3
# Out:
# {u'A0': [114, 111, 112, 114, 113, 111, 114],
#  u'A1': [230, 230, 232, 235, 234, 235, 233],
#  u'A2': [152, 149, 152, 152, 154, 152, 154],
#  u'A3': [243, 244, 246, 248, 247, 248, 248],
#  u'A4': [210, 251, 278, 315, 341, 348, 351],
#  u'A5': [81, 128, 165, 215, 267, 296, 296],
#  u'A6': [55, 77, 95, 104, 119, 125, 141]}

# %%
plot_series(series3)

# %%
from scipy.optimize import curve_fit

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a * np.exp(-b * x) + c

x = np.linspace(0,4,50)
y = func(x, 2.5, 1.3, 0.5)
yn = y + 0.2*np.random.normal(size=len(x))

popt, pcov = curve_fit(func, x, yn)

# %%
plt.figure()
plt.plot(x, yn, 'ko', label="Original Noised Data")
plt.plot(x, func(x, *popt), 'r-', label="Fitted Curve")
plt.legend()
plt.show()
